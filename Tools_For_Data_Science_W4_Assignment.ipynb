# %% [markdown]
# <H1>My Jupyter Notebook on Google Colab</H1>

# %% [markdown]
# **Anvar Nurmatov**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I am passionate about using data and analytical tools to solve complex problems and make data-driven decisions.*

# %% [markdown]
# <H3>The code in this cell will calculate the sum of two numbers.</H3>

# %%
x = 3
y = 4
sum = x + y
print(sum)
# Out:
# 7

# %% [markdown]
# Bulleted list:
#
# * Item 1
# * Item 2
# * Item 3
#
# Numbered list:
#
# 1. Item 1
# 2. Item 2
# 3. Item 3
#
# Table:
#
# | Column 1 |	Column 2 |
# | --- | --- |
# |Cell 1 |	Cell 2 |
# |Cell 3	| Cell 4 |
#
# Code:
#
# ```python
# def hello():
#     print("Hello, World!")
# ```
#
# And quote:
#
# > This is a block quote.
